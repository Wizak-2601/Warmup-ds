# %%
# 1. Import numpy as np
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 2
#       1 # 1. Import numpy as np
# ----> 2 import numpy as np
#
# ModuleNotFoundError: No module named 'numpy'

# %%
# 2. Print numpy version and configuration
print("NumPy version:", np.__version__)
np.show_config()

# %%
# 3. Create a null vector of size 10
v3 = np.zeros(10)
v3

# %%
# 4. Find the memory size of any array
print("memory size (bytes):", v3.nbytes)

# %%
# 6. Null vector of size 10 with fifth value = 1
v6 = np.zeros(10)
v6[4] = 1
v6

# %%
# 7. Vector with values from 10 to 49
v7 = np.arange(10, 50)
v7

# %%
# 8. Reverse a vector
v8 = v7[::-1]
v8

# %%
m9 = np.arange(9).reshape(3, 3)
m9

# %%
arr10 = np.array([1, 2, 0, 0, 4, 0])
nz10 = np.nonzero(arr10)
nz10

# %%
# 11. 3x3 identity matrix
m11 = np.eye(3)
m11

# %%
# 12. 3x3x3 array with random values
a12 = np.random.random((3, 3, 3))
a12

# %%
# 13. 10x10 random array and min/max
a13 = np.random.random((10, 10))
print("min =", a13.min(), "max =", a13.max())

# %%
# 14. Random vector of size 30 and mean
v14 = np.random.random(30)
print("mean =", v14.mean())

# %%
# 15. 2D array with 1 on border and 0 inside
a15 = np.ones((5, 5))
a15[1:-1, 1:-1] = 0
a15

# %%
# 16. Add a zero border around an existing array
a16 = np.pad(a15, pad_width=1, mode='constant', constant_values=0)
a16

# %%
# 17. Results of expressions
print(0 * np.nan)             # nan
print(np.nan == np.nan)       # False
print(np.inf > np.nan)        # False
print(np.nan - np.nan)        # nan
print(np.nan in set([np.nan]))# True
print(0.3 == 3 * 0.1)         # False

# %%
# 18. 5x5 matrix with values 1,2,3,4 below the diagonal
m18 = np.diag([1, 2, 3, 4], k=-1)
m18

# %%
# 19. 8x8 checkerboard pattern
checker19 = np.zeros((8, 8), dtype=int)
checker19[1::2, ::2] = 1
checker19[::2, 1::2] = 1
checker19

# %%
# 20. Index of the 100th element in a (6,7,8) array
idx20 = np.unravel_index(99, (6, 7, 8))
idx20

# %%
# 21. Checkerboard using tile
checker21 = np.tile([[0, 1], [1, 0]], (4, 4))
checker21

# %%
# 22. Normalize a 5x5 random matrix
a22 = np.random.random((5, 5))
a22 = (a22 - a22.min()) / (a22.max() - a22.min())
a22

# %%
# 23. Custom dtype for RGBA
color_dtype = np.dtype([
    ('r', np.uint8),
    ('g', np.uint8),
    ('b', np.uint8),
    ('a', np.uint8)
])
color_dtype

# %%
# 24. Multiply 5x3 matrix by 3x2 matrix
A = np.random.random((5, 3))
B = np.random.random((3, 2))
C = A @ B
C

# %%
# 25. Negate elements between 3 and 8 (in place)
arr25 = np.array([1, 4, 6, 9, 2, 7])
arr25[(arr25 > 3) & (arr25 < 8)] *= -1
arr25

# %%
# 26. Output of the following script
print(sum(range(5), -1))
from numpy import *
print(sum(range(5), -1))

# %%
# 28. Results of expressions
print(np.array(0) / np.array(0))                # nan
print(np.array(0) // np.array(0))               # 0 (warning)
print(np.array([np.nan]).astype(int).astype(float))

# %%
# 29. Round away from zero
Z29 = np.array([-1.2, 1.2, -2.7, 2.7])
Z29_round = np.copysign(np.ceil(np.abs(Z29)), Z29)
Z29_round

# %%
# 30. Find common values between two arrays
A30 = np.array([1, 2, 3, 4])
B30 = np.array([3, 4, 5, 6])
np.intersect1d(A30, B30)

# %%
# 31. Ignore all numpy warnings
np.seterr(all='ignore')

# %%
# 32. Is the expression true?
print(np.sqrt(-1) == np.emath.sqrt(-1))

# %%
# 33. Yesterday, today and tomorrow
today = np.datetime64('today')
yesterday = today - np.timedelta64(1, 'D')
tomorrow = today + np.timedelta64(1, 'D')
print(yesterday, today, tomorrow)

# %%
# 34. Dates of July 2016
dates34 = np.arange('2016-07', '2016-08', dtype='datetime64[D]')
dates34

# %%
# 35. Compute ((A+B)*(-A/2)) in place
A35 = np.random.random((3, 3))
B35 = np.random.random((3, 3))
np.add(A35, B35, out=A35)
np.multiply(A35, -A35/2, out=A35)
A35

# %%
# 36. Extract integer part (4 methods)
Z36 = np.random.random(10) * 10
print(np.floor(Z36))
print(np.trunc(Z36))
print(Z36.astype(int))
print(Z36 // 1)

# %%
# 37. 5x5 matrix with rows 0 to 4
M37 = np.tile(np.arange(5), (5, 1))
M37

# %%
# 38. Build array from generator
def gen38():
    for i in range(10):
        yield i
A38 = np.fromiter(gen38(), dtype=int)
A38

# %%
# 39. Vector of size 10 with values in (0,1)
V39 = np.linspace(0, 1, 12)[1:-1]
V39

# %%
# 40. Random vector and sort
V40 = np.random.random(10)
V40.sort()
V40

# %%
# 41. Sum faster than np.sum for small arrays
Z41 = np.arange(10)
np.add.reduce(Z41)

# %%
# 42. Check if two arrays are equal
A42 = np.array([1, 2, 3])
B42 = np.array([1, 2, 3])
np.array_equal(A42, B42)

# %%
# 43. Make array immutable
Z43 = np.array([1, 2, 3])
Z43.flags.writeable = False
Z43.flags.writeable

# %%
# 44. Cartesian to polar coordinates
Z44 = np.random.random((10, 2))
x, y = Z44[:, 0], Z44[:, 1]
r = np.sqrt(x**2 + y**2)
theta = np.arctan2(y, x)
print("r =", r, "\ntheta =", theta)

# %%
# 45. Replace maximum value with 0
Z45 = np.random.random(10)
Z45[Z45.argmax()] = 0
Z45

# %%
# 46. Structured array with x,y in [0,1]x[0,1]
x46, y46 = np.meshgrid(np.linspace(0, 1, 5), np.linspace(0, 1, 5))
Z46 = np.zeros(x46.shape, dtype=[('x', float), ('y', float)])
Z46['x'], Z46['y'] = x46, y46
Z46

# %%
# 47. Cauchy matrix
X47 = np.array([1, 2, 3])
Y47 = np.array([4, 5, 6])
C47 = 1.0 / (X47[:, None] - Y47[None, :])
C47

# %%
# 48. Min and max representable values
for dtype in [np.int8, np.int16, np.int32, np.int64,
              np.uint8, np.uint16, np.uint32, np.uint64,
              np.float32, np.float64]:
    info = np.iinfo(dtype) if np.issubdtype(dtype, np.integer) else np.finfo(dtype)
    print(dtype, info.min, info.max)

# %%
# 49. Print all values of an array
np.set_printoptions(threshold=np.inf)
print(C47)

# %%
# 50. Closest value to a scalar
Z50 = np.array([0.1, 0.4, 0.8, 1.2])
value = 0.9
closest = Z50[np.abs(Z50 - value).argmin()]
closest
