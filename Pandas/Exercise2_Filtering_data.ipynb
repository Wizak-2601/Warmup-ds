# %% [markdown]
# # Ex2 - Getting and Knowing your Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
chipo = pd.read_csv(url, sep='\t')

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
# Solution 1
num_observations = chipo.shape[0]
print(num_observations)
# Out:
# 4622

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
num_columns = chipo.shape[1]
print(num_columns)
# Out:
# 5

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
print(chipo.columns.tolist())
# Out:
# ['order_id', 'quantity', 'item_name', 'choice_description', 'item_price']

# %% [markdown]
# ### Step 8. How is the dataset indexed?

# %%
print(chipo.index)
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# ### Step 9. Which was the most-ordered item?

# %%
grouped = chipo.groupby('item_name')['quantity'].sum()
most_ordered = grouped.sort_values(ascending=False).head(1)
print(most_ordered)
# Out:
# item_name
# Chicken Bowl    761
# Name: quantity, dtype: int64

# %% [markdown]
# ### Step 10. For the most-ordered item, how many items were ordered?

# %%
quantity = most_ordered.iloc[0]
print(quantity)
# Out:
# 761

# %% [markdown]
# ### Step 11. What was the most ordered item in the choice_description column?

# %%
most_choice = (
    chipo.groupby('choice_description', as_index=False)['quantity']
    .sum()
    .sort_values('quantity', ascending=False)
    .head(1)
)

print(most_choice)
# Out:
#    choice_description  quantity
# 15        [Diet Coke]       159

# %% [markdown]
# ### Step 12. How many items were orderd in total?

# %%
total_items = chipo['quantity'].sum()
print(total_items)
# Out:
# 4972

# %% [markdown]
# ### Step 13. Turn the item price into a float

# %% [markdown]
# #### Step 13.a. Check the item price type

# %%
print(chipo.item_price.dtype)
# Out:
# object

# %% [markdown]
# #### Step 13.b. Create a lambda function and change the type of item price

# %%
chipo['item_price'] = chipo['item_price'].apply(lambda x: float(x.replace('$','')))

# %% [markdown]
# #### Step 13.c. Check the item price type

# %%
print(chipo.item_price.dtype)
# Out:
# float64

# %% [markdown]
# ### Step 14. How much was the revenue for the period in the dataset?

# %%
revenue = (chipo['quantity'] * chipo['item_price']).sum()
print(f'Revenue was: ${revenue:.2f}')
# Out:
# Revenue was: $39237.02

# %% [markdown]
# ### Step 15. How many orders were made in the period?

# %%
num_orders = chipo['order_id'].nunique()
print(num_orders)
# Out:
# 1834

# %% [markdown]
# ### Step 16. What is the average revenue amount per order?

# %%
order_revenue = chipo.groupby('order_id').apply(
    lambda df: (df.quantity * df.item_price).sum()
)
avg_revenue = order_revenue.mean()
print(avg_revenue)
# Out:
# 21.39423118865867
# /tmp/ipython-input-3799603352.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   order_revenue = chipo.groupby('order_id').apply(

# %% [markdown]
# ### Step 17. How many different items are sold?

# %%
num_unique_items = chipo['item_name'].nunique()
print(num_unique_items)
# Out:
# 50
